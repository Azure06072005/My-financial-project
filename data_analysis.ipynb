# %%
import pandas as pd
import io
import os
import matplotlib.pyplot
import seaborn as sns 
import numpy as np

# %%
def process_excel_sheet(excel_path, sheet_name): 
    try: 
        print(f"Reading sheet {sheet_name} from {os.path.basename(excel_path)}")
        
        df = pd.read_excel(excel_path, sheet_name=sheet_name, header=5, index_col=0)
        
        df.dropna(how='all', axis=0, inplace=True)
        df.dropna(how='all', axis=1, inplace=True)
        
        df.index.name = 'Chỉ tiêu'
        df.columns.Name = 'Quý'
        
        print(f"Successfully processed sheet {sheet_name} \n")
        return df

    except ValueError: 
        print(f"Error: Sheet {sheet_name} not found in {excel_path}. Please check the sheet name.")
        return None
    except Exception as e: 
        print(f"An unexpected error occurred while processing sheet {sheet_name}: {e}")
        return None

def analyze_financials(): 
    # 1. Enter valid Excel file path 
    while True: 
        file_path = input("Please enter the full path to your financial Excel file: ")
        # Check if the path exists an if the file has an .xlsx or .xls extension
        if os.path.exists(file_path) and file_path.lower().endswith(('.xlsx', '.xls')):
            print(f"File found: {file_path}! \n")
            break
        else:
            print(f"File path {file_path} is not found ! Please check again")
            
    # 2. Define sheet names 
    sheet_mapping = {
        'balance_sheet' : 'CDKT',
        'income_statement' : 'KQKD',
        'financial_ratios' : 'CSTC'
    }
    
    # 3. Read data from each sheet into a dictionary of Dataframes
    financial_dataframes = {}
    for df_key, sheet_name in sheet_mapping.items(): 
        financial_dataframes[df_key] = process_excel_sheet(file_path, sheet_name)
        
    # 4. Display the head of each successfully loaded Dataframe
    df_bs = financial_dataframes.get('balance_sheet')
    if df_bs is not None: 
        print("--- Balance Sheet (Cân đối kế toán) ---")
        print(df_bs.head(1000))
        print("\n" + "="*70 + "\n")
        
    df_is = financial_dataframes.get('income_statement')
    if df_is is not None:
        print("--- Income Statement (Kết quả kinh doanh) ---")
        print(df_is.head(1000))
        print("\n" + "="*70 + "\n")

    df_fr = financial_dataframes.get('financial_ratios')
    if df_fr is not None:
        print("--- Financial Ratios (Chỉ số tài chính) ---")
        print(df_fr.head(1000))
        print("\n" + "="*70 + "\n")

# %%
analyze_financials()
# Out:
# File found: D:\financial_project\HPG_hn_Q2_2025.xlsx!
#
# Reading sheet CDKT from HPG_hn_Q2_2025.xlsx
# Successfully processed sheet CDKT
#
# Reading sheet KQKD from HPG_hn_Q2_2025.xlsx
# Successfully processed sheet KQKD
#
# Reading sheet CSTC from HPG_hn_Q2_2025.xlsx
# Successfully processed sheet CSTC
#
# --- Balance Sheet (Cân đối kế toán) ---
#                                             Q2/2024         Q3/2024  \
# Chỉ tiêu
# Giai đoạn                               01/04-30/06     01/07-30/09
# Hợp nhất                                   Hợp nhất        Hợp nhất
# Kiểm toán                            Chưa kiểm toán  Chưa kiểm toán
# Tài sản ngắn hạn                              84467           80842
# Tiền và các khoản tương đương tiền            13032            8501
# Các khoản đầu tư tài chính ngắn hạn           15315           16387
# Các khoản phải thu ngắn hạn                   10393            9141
# Hàng tồn kho                                  40164           40198
# Tài sản ngắn hạn khác                          5564            6615
# Tài sản dài hạn                              122142          130545
# Tài sản cố định                               70075           68476
# Bất động sản đầu tư                             576             568
# Các khoản đầu tư tài chính dài hạn              137             137
# Tổng cộng tài sản                            206609          211386
# Nợ phải trả                                   97933           99607
# Nợ ngắn hạn                                   73551           68995
# Nợ dài hạn                                    24381           30612
# Vốn chủ sở hữu                               108677          111779
# Vốn đầu tư của chủ sở hữu                     63963           63963
# Lợi nhuận sau thuế chưa phân phối             43793           46809
# Tổng cộng nguồn vốn                          206609          211386
#
#                                             Q4/2024         Q1/2025  \
# Chỉ tiêu
# Giai đoạn                               01/10-31/12     01/01-31/03
# Hợp nhất                                   Hợp nhất        Hợp nhất
# Kiểm toán                            Chưa kiểm toán  Chưa kiểm toán
# Tài sản ngắn hạn                              87079           88914
# Tiền và các khoản tương đương tiền             6888            7459
# Các khoản đầu tư tài chính ngắn hạn           18975           16213
# Các khoản phải thu ngắn hạn                    7622           10856
# Hàng tồn kho                                  46521           46604
# Tài sản ngắn hạn khác                          7073            7783
# Tài sản dài hạn                              137411          139947
# Tài sản cố định                               67428           85838
# Bất động sản đầu tư                             560             553
# Các khoản đầu tư tài chính dài hạn              137             NaN
# Tổng cộng tài sản                            224490          228862
# Nợ phải trả                                  109842          110865
# Nợ ngắn hạn                                   75503           77299
# Nợ dài hạn                                    34339           33566
# Vốn chủ sở hữu                               114647          117997
# Vốn đầu tư của chủ sở hữu                     63963           63963
# Lợi nhuận sau thuế chưa phân phối             49576           52944
# Tổng cộng nguồn vốn                          224490          228862
#
#                                             Q2/2025
# Chỉ tiêu
# Giai đoạn                               01/04-30/06
# Hợp nhất                                   Hợp nhất
# Kiểm toán                            Chưa kiểm toán
# Tài sản ngắn hạn                              97606
# Tiền và các khoản tương đương tiền            10688
# Các khoản đầu tư tài chính ngắn hạn           17584
# Các khoản phải thu ngắn hạn                   12327
# Hàng tồn kho                                  48853
# Tài sản ngắn hạn khác                          8154
# Tài sản dài hạn                              144618
# Tài sản cố định                               65303
# Bất động sản đầu tư                             544
# Các khoản đầu tư tài chính dài hạn              NaN
# Tổng cộng tài sản                            242225
# Nợ phải trả                                  119865
# Nợ ngắn hạn                                   86412
# Nợ dài hạn                                    33453
# Vốn chủ sở hữu                               122360
# Vốn đầu tư của chủ sở hữu                     63963
# Lợi nhuận sau thuế chưa phân phối             56177
# Tổng cộng nguồn vốn                          242225
#
# ======================================================================
#
# --- Income Statement (Kết quả kinh doanh) ---
#                                                         Q2/2024  \
# Chỉ tiêu
# Giai đoạn                                           01/04-30/06
# Hợp nhất                                               Hợp nhất
# Kiểm toán                                        Chưa kiểm toán
# Doanh thu thuần về bán hàng và cung cấp dịch vụ           39556
# Giá vốn hàng bán                                          34308
# Lợi nhuận gộp về bán hàng và cung cấp dịch vụ              5247
# Doanh thu hoạt động tài chính                               645
# Chi phí tài chính                                          1065
# Chi phí bán hàng                                            747
# Chi phí quản lý doanh nghiệp                                389
# Lợi nhuận thuần từ hoạt động kinh doanh                    3692
# Lợi nhuận khác                                               42
# Tổng lợi nhuận kế toán trước thuế                          3733
# Lợi nhuận sau thuế thu nhập doanh nghiệp                   3320
# Lợi nhuận sau thuế của cổ đông Công ty mẹ                  3319
#
#                                                         Q3/2024  \
# Chỉ tiêu
# Giai đoạn                                           01/07-30/09
# Hợp nhất                                               Hợp nhất
# Kiểm toán                                        Chưa kiểm toán
# Doanh thu thuần về bán hàng và cung cấp dịch vụ           33956
# Giá vốn hàng bán                                          29225
# Lợi nhuận gộp về bán hàng và cung cấp dịch vụ              4731
# Doanh thu hoạt động tài chính                               528
# Chi phí tài chính                                           833
# Chi phí bán hàng                                            720
# Chi phí quản lý doanh nghiệp                                322
# Lợi nhuận thuần từ hoạt động kinh doanh                    3385
# Lợi nhuận khác                                               27
# Tổng lợi nhuận kế toán trước thuế                          3412
# Lợi nhuận sau thuế thu nhập doanh nghiệp                   3022
# Lợi nhuận sau thuế của cổ đông Công ty mẹ                  3023
#
#                                                         Q4/2024  \
# Chỉ tiêu
# Giai đoạn                                           01/10-31/12
# Hợp nhất                                               Hợp nhất
# Kiểm toán                                        Chưa kiểm toán
# Doanh thu thuần về bán hàng và cung cấp dịch vụ           34491
# Giá vốn hàng bán                                          30126
# Lợi nhuận gộp về bán hàng và cung cấp dịch vụ              4365
# Doanh thu hoạt động tài chính                               701
# Chi phí tài chính                                          1015
# Chi phí bán hàng                                            230
# Chi phí quản lý doanh nghiệp                                517
# Lợi nhuận thuần từ hoạt động kinh doanh                    3303
# Lợi nhuận khác                                              -16
# Tổng lợi nhuận kế toán trước thuế                          3287
# Lợi nhuận sau thuế thu nhập doanh nghiệp                   2810
# Lợi nhuận sau thuế của cổ đông Công ty mẹ                  2807
#
#                                                         Q1/2025  \
# Chỉ tiêu
# Giai đoạn                                           01/01-31/03
# Hợp nhất                                               Hợp nhất
# Kiểm toán                                        Chưa kiểm toán
# Doanh thu thuần về bán hàng và cung cấp dịch vụ           37622
# Giá vốn hàng bán                                          32198
# Lợi nhuận gộp về bán hàng và cung cấp dịch vụ              5424
# Doanh thu hoạt động tài chính                               438
# Chi phí tài chính                                           971
# Chi phí bán hàng                                            738
# Chi phí quản lý doanh nghiệp                                347
# Lợi nhuận thuần từ hoạt động kinh doanh                    3807
# Lợi nhuận khác                                               33
# Tổng lợi nhuận kế toán trước thuế                          3840
# Lợi nhuận sau thuế thu nhập doanh nghiệp                   3350
# Lợi nhuận sau thuế của cổ đông Công ty mẹ                  3344
#
#                                                         Q2/2025
# Chỉ tiêu
# Giai đoạn                                           01/04-30/06
# Hợp nhất                                               Hợp nhất
# Kiểm toán                                        Chưa kiểm toán
# Doanh thu thuần về bán hàng và cung cấp dịch vụ           35911
# Giá vốn hàng bán                                          29321
# Lợi nhuận gộp về bán hàng và cung cấp dịch vụ              6590
# Doanh thu hoạt động tài chính                               498
# Chi phí tài chính                                           979
# Chi phí bán hàng                                            825
# Chi phí quản lý doanh nghiệp                                322
# Lợi nhuận thuần từ hoạt động kinh doanh                    4961
# Lợi nhuận khác                                               12
# Tổng lợi nhuận kế toán trước thuế                          4972
# Lợi nhuận sau thuế thu nhập doanh nghiệp                   4265
# Lợi nhuận sau thuế của cổ đông Công ty mẹ                  4257
#
# ======================================================================
#
# --- Financial Ratios (Chỉ số tài chính) ---
#                                                    Unnamed: 1         Q2/2024  \
# Chỉ tiêu
# Giai đoạn                                                 NaN     01/04-30/06
# Hợp nhất                                                  NaN        Hợp nhất
# Kiểm toán                                                 NaN  Chưa kiểm toán
# Thu nhập trên mỗi cổ phần của 4 quý gần nhất (EPS)        VNĐ         1905.91
# Giá trị sổ sách của cổ phiếu (BVPS)                       VNĐ           16991
# Chỉ số giá thị trường trên thu nhập (P/E)                 Lần           14.85
# Chỉ số giá thị trường trên giá trị sổ sách (P/B)          Lần            1.67
# Tỷ suất lợi nhuận gộp biên                                  %           13.27
# Tỷ suất sinh lợi trên doanh thu thuần                       %            8.39
# Tỷ suất lợi nhuận trên vốn chủ sở hữu bình quân...          %             3.1
# Tỷ suất sinh lợi trên tổng tài sản bình quân (R...          %            1.62
# Tỷ số thanh toán hiện hành (ngắn hạn)                     Lần            1.15
# Khả năng thanh toán lãi vay                               Lần            7.62
# Tỷ số Nợ trên Tổng tài sản                                  %            47.4
# Tỷ số Nợ vay trên Vốn chủ sở hữu                            %           67.16
#
#                                                            Q3/2024  \
# Chỉ tiêu
# Giai đoạn                                              01/07-30/09
# Hợp nhất                                                  Hợp nhất
# Kiểm toán                                           Chưa kiểm toán
# Thu nhập trên mỗi cổ phần của 4 quý gần nhất (EPS)         2028.02
# Giá trị sổ sách của cổ phiếu (BVPS)                          17476
# Chỉ số giá thị trường trên thu nhập (P/E)                    12.99
# Chỉ số giá thị trường trên giá trị sổ sách (P/B)              1.51
# Tỷ suất lợi nhuận gộp biên                                   13.93
# Tỷ suất sinh lợi trên doanh thu thuần                          8.9
# Tỷ suất lợi nhuận trên vốn chủ sở hữu bình quân...            2.74
# Tỷ suất sinh lợi trên tổng tài sản bình quân (R...            1.45
# Tỷ số thanh toán hiện hành (ngắn hạn)                         1.17
# Khả năng thanh toán lãi vay                                    7.5
# Tỷ số Nợ trên Tổng tài sản                                   47.12
# Tỷ số Nợ vay trên Vốn chủ sở hữu                             70.41
#
#                                                            Q4/2024  \
# Chỉ tiêu
# Giai đoạn                                              01/10-31/12
# Hợp nhất                                                  Hợp nhất
# Kiểm toán                                           Chưa kiểm toán
# Thu nhập trên mỗi cổ phần của 4 quý gần nhất (EPS)         1950.81
# Giá trị sổ sách của cổ phiếu (BVPS)                          17924
# Chỉ số giá thị trường trên thu nhập (P/E)                    13.66
# Chỉ số giá thị trường trên giá trị sổ sách (P/B)              1.49
# Tỷ suất lợi nhuận gộp biên                                   12.66
# Tỷ suất sinh lợi trên doanh thu thuần                         8.15
# Tỷ suất lợi nhuận trên vốn chủ sở hữu bình quân...            2.48
# Tỷ suất sinh lợi trên tổng tài sản bình quân (R...            1.29
# Tỷ số thanh toán hiện hành (ngắn hạn)                         1.15
# Khả năng thanh toán lãi vay                                   6.84
# Tỷ số Nợ trên Tổng tài sản                                   48.93
# Tỷ số Nợ vay trên Vốn chủ sở hữu                             72.36
#
#                                                            Q1/2025  \
# Chỉ tiêu
# Giai đoạn                                              01/01-31/03
# Hợp nhất                                                  Hợp nhất
# Kiểm toán                                           Chưa kiểm toán
# Thu nhập trên mỗi cổ phần của 4 quý gần nhất (EPS)         1983.64
# Giá trị sổ sách của cổ phiếu (BVPS)                          18448
# Chỉ số giá thị trường trên thu nhập (P/E)                    13.49
# Chỉ số giá thị trường trên giá trị sổ sách (P/B)              1.45
# Tỷ suất lợi nhuận gộp biên                                   14.42
# Tỷ suất sinh lợi trên doanh thu thuần                          8.9
# Tỷ suất lợi nhuận trên vốn chủ sở hữu bình quân...            2.88
# Tỷ suất sinh lợi trên tổng tài sản bình quân (R...            1.48
# Tỷ số thanh toán hiện hành (ngắn hạn)                         1.15
# Khả năng thanh toán lãi vay                                   7.12
# Tỷ số Nợ trên Tổng tài sản                                   48.44
# Tỷ số Nợ vay trên Vốn chủ sở hữu                             75.46
#
#                                                            Q2/2025
# Chỉ tiêu
# Giai đoạn                                              01/04-30/06
# Hợp nhất                                                  Hợp nhất
# Kiểm toán                                           Chưa kiểm toán
# Thu nhập trên mỗi cổ phần của 4 quý gần nhất (EPS)         2099.79
# Giá trị sổ sách của cổ phiếu (BVPS)                          19130
# Chỉ số giá thị trường trên thu nhập (P/E)                    10.81
# Chỉ số giá thị trường trên giá trị sổ sách (P/B)              1.19
# Tỷ suất lợi nhuận gộp biên                                   18.35
# Tỷ suất sinh lợi trên doanh thu thuần                        11.88
# Tỷ suất lợi nhuận trên vốn chủ sở hữu bình quân...            3.54
# Tỷ suất sinh lợi trên tổng tài sản bình quân (R...            1.81
# Tỷ số thanh toán hiện hành (ngắn hạn)                         1.13
# Khả năng thanh toán lãi vay                                  12.32
# Tỷ số Nợ trên Tổng tài sản                                   49.49
# Tỷ số Nợ vay trên Vốn chủ sở hữu                             74.04
#
# ======================================================================
